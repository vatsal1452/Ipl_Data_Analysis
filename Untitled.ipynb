# %% [markdown]
# Data Analysis on IPL DATASET

# %%
#importing requried libary

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# loading dataset
df=pd.read_csv('ipl.csv')

# %%
#geting head of dataframe

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.tail() # getting last 5 row
# Out:
#         id  season           city      date                  team1  \
# 751  11347    2019         Mumbai  05/05/19  Kolkata Knight Riders
# 752  11412    2019        Chennai  07/05/19    Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08/05/19    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10/05/19         Delhi Capitals
# 755  11415    2019      Hyderabad  12/05/19         Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 751           0       Mumbai Indians            0               9
# ...

# %%
# getting dimension of dataframe
df.shape
# Out:
# (756, 18)

# %%
df.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
# Analyzing data on player_of match

# %%
df['player_of_match'].head()
# Out:
# 0    Yuvraj Singh
# 1       SPD Smith
# 2         CA Lynn
# 3      GJ Maxwell
# 4       KM Jadhav
# Name: player_of_match, dtype: object

# %%
# getting count of player_of_match count

# %%
df['player_of_match'].value_counts()
# Out:
# CH Gayle           21
# AB de Villiers     20
# DA Warner          17
# RG Sharma          17
# MS Dhoni           17
#                    ..
# DL Vettori          1
# K Rabada            1
# AA Jhunjhunwala     1
# S Anirudha          1
# Kuldeep Yadav       1
# Name: player_of_match, Length: 226, dtype: int64

# %%
df['player_of_match'].value_counts().head()
# Out:
# CH Gayle          21
# AB de Villiers    20
# DA Warner         17
# RG Sharma         17
# MS Dhoni          17
# Name: player_of_match, dtype: int64

# %%
df['player_of_match'].value_counts()[0:10] #getting list of player with max number of "player_of_match"
# Out:
# CH Gayle          21
# AB de Villiers    20
# DA Warner         17
# RG Sharma         17
# MS Dhoni          17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# V Kohli           12
# Name: player_of_match, dtype: int64

# %%
df['player_of_match'].value_counts()[:10].keys()
# Out:
# Index(['CH Gayle', 'AB de Villiers', 'DA Warner', 'RG Sharma', 'MS Dhoni',
#        'YK Pathan', 'SR Watson', 'SK Raina', 'G Gambhir', 'V Kohli'],
#       dtype='object')

# %%
# Ploting barplot forshowing data of max numbr of player_of_match

# %%
plt.bar(df['player_of_match'].value_counts()[:5].keys(),df['player_of_match'].value_counts()[:5])
plt.title("Player_of_Match")
plt.show()

# %%
sns.distplot(df['player_of_match'].value_counts()[:10])

# %%
sns.distplot(df['player_of_match'].value_counts()[:10],hist=False)

# %%
df['result'].head()
# Out:
# 0    normal
# 1    normal
# 2    normal
# 3    normal
# 4    normal
# Name: result, dtype: object

# %%
df['result'].value_counts()
# Out:
# normal       743
# tie            9
# no result      4
# Name: result, dtype: int64

# %%
df['toss_winner'].head()
# Out:
# 0    Royal Challengers Bangalore
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# Name: toss_winner, dtype: object

# %%
df['toss_winner'].value_counts()
# Out:
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Rajasthan Royals               80
# Delhi Daredevils               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %%
df['toss_winner'].value_counts().mean()
# Out:
# 50.4

# %%
(df['toss_winner'].value_counts().median())
# Out:
# 46.0

# %%
sns.barplot(df['toss_winner'].value_counts()[:5].keys(),df['toss_winner'].value_counts()[:5])

# %%
plt.pie(df['toss_winner'].value_counts()[:5],labels=df['toss_winner'].value_counts()[:5].keys(),autopct='%1.1f%%')
plt.show()

# %%
# Analyzing data of team batting first

# %%
df["win_by_runs"]
# Out:
# 0      35
# 1       0
# 2       0
# 3       0
# 4      15
#        ..
# 751     0
# 752     0
# 753     0
# 754     0
# 755     1
# Name: win_by_runs, Length: 756, dtype: int64

# %%
bat_first_win=df[df['win_by_runs']!=0]

# %%
bat_first_win
# Out:
#         id  season       city        date                        team1  \
# 0        1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 4        5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 8        9    2017       Pune  2017-04-11             Delhi Daredevils
# 13      14    2017    Kolkata  2017-04-15        Kolkata Knight Riders
# 14      15    2017      Delhi  2017-04-15             Delhi Daredevils
# ..     ...     ...        ...         ...                          ...
# 741  11337    2019      Delhi    28/04/19               Delhi Capitals
# 742  11338    2019    Kolkata    28/04/19        Kolkata Knight Riders
# 743  11339    2019  Hyderabad    29/04/19          Sunrisers Hyderabad
# 745  11341    2019    Chennai    01/05/19          Chennai Super Kings
# 755  11415    2019  Hyderabad    12/05/19               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
bat_first_win['winner']
# Out:
# 0              Sunrisers Hyderabad
# 4      Royal Challengers Bangalore
# 8                 Delhi Daredevils
# 13           Kolkata Knight Riders
# 14                Delhi Daredevils
#                   ...
# 741                 Delhi Capitals
# 742          Kolkata Knight Riders
# 743            Sunrisers Hyderabad
# 745            Chennai Super Kings
# 755                 Mumbai Indians
# Name: winner, Length: 337, dtype: object

# %%
bat_first_win['winner'].value_counts()
# Out:
# Mumbai Indians                 57
# Chennai Super Kings            52
# Kings XI Punjab                38
# Kolkata Knight Riders          36
# Royal Challengers Bangalore    35
# Sunrisers Hyderabad            30
# Rajasthan Royals               27
# Delhi Daredevils               25
# Deccan Chargers                18
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Delhi Capitals                  3
# Kochi Tuskers Kerala            2
# Rising Pune Supergiants         2
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %%
(bat_first_win['winner'].value_counts()).count() # value of total team won least one match
# Out:
# 15

# %%
bat_first_win['winner'].head()
# Out:
# 0             Sunrisers Hyderabad
# 4     Royal Challengers Bangalore
# 8                Delhi Daredevils
# 13          Kolkata Knight Riders
# 14               Delhi Daredevils
# Name: winner, dtype: object

# %%
bat_first_win['winner'].value_counts().mean()
# Out:
# 22.466666666666665

# %%
bat_first_win['winner'].value_counts().median()
# Out:
# 25.0

# %%
sns.distplot(bat_first_win['winner'].value_counts(),bins=5)

# %%
sns.distplot(bat_first_win['winner'].value_counts(),bins=5,kde=False)

# %%
sns.distplot(bat_first_win['winner'].value_counts(),bins=5,hist=False)

# %%
sns.barplot(bat_first_win['winner'].value_counts()[:5].keys(),bat_first_win['winner'].value_counts()[:5])

# %%
sns.barplot(bat_first_win['winner'].value_counts()[5:10].keys(),bat_first_win['winner'].value_counts()[5:10])

# %%
plt.pie(bat_first_win['winner'].value_counts()[:5],labels=bat_first_win['winner'].value_counts()[:5].keys(),autopct='%1.1f%%')
plt.show()

# %%
plt.pie(bat_first_win['winner'].value_counts()[5:10],labels=bat_first_win['winner'].value_counts()[5:10].keys(),autopct='%1.1f%%')
plt.show()

# %%
#Analysing Victory of Team Bolwing first

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
bol_win=df[df['win_by_wickets']!=0]

# %%
bol_win
# Out:
#         id  season           city        date                   team1  \
# 1        2    2017           Pune  2017-04-06          Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07           Gujarat Lions
# 3        4    2017         Indore  2017-04-08  Rising Pune Supergiant
# 5        6    2017      Hyderabad  2017-04-09           Gujarat Lions
# 6        7    2017         Mumbai  2017-04-09   Kolkata Knight Riders
# ..     ...     ...            ...         ...                     ...
# 750  11346    2019         Mohali    05/05/19     Chennai Super Kings
# 751  11347    2019         Mumbai    05/05/19   Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19     Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19     Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19          Delhi Capitals
#
#                       team2             toss_winner toss_decision  result  \
# ...

# %%
bol_win.head()
# Out:
#    id  season       city        date                   team1  \
# 1   2    2017       Pune  2017-04-06          Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07           Gujarat Lions
# 3   4    2017     Indore  2017-04-08  Rising Pune Supergiant
# 5   6    2017  Hyderabad  2017-04-09           Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09   Kolkata Knight Riders
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 2   Kolkata Knight Riders   Kolkata Knight Riders         field  normal
# 3         Kings XI Punjab         Kings XI Punjab         field  normal
# 5     Sunrisers Hyderabad     Sunrisers Hyderabad         field  normal
# 6          Mumbai Indians          Mumbai Indians         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# ...

# %%
bol_win.shape
# Out:
# (406, 18)

# %%
bol_win['winner']
# Out:
# 1      Rising Pune Supergiant
# 2       Kolkata Knight Riders
# 3             Kings XI Punjab
# 5         Sunrisers Hyderabad
# 6              Mumbai Indians
#                 ...
# 750           Kings XI Punjab
# 751            Mumbai Indians
# 752            Mumbai Indians
# 753            Delhi Capitals
# 754       Chennai Super Kings
# Name: winner, Length: 406, dtype: object

# %%
bol_win['winner'].value_counts()
# Out:
# Kolkata Knight Riders          56
# Mumbai Indians                 50
# Royal Challengers Bangalore    48
# Chennai Super Kings            48
# Rajasthan Royals               46
# Delhi Daredevils               42
# Kings XI Punjab                42
# Sunrisers Hyderabad            27
# Gujarat Lions                  12
# Deccan Chargers                11
# Delhi Capitals                  6
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Name: winner, dtype: int64

# %%
(bol_win['winner'].value_counts()).count()
# Out:
# 15

# %%
v=[bol_win['winner'].value_counts()]
type(v)
# Out:
# list

# %%
v
# Out:
# [Kolkata Knight Riders          56
#  Mumbai Indians                 50
#  Royal Challengers Bangalore    48
#  Chennai Super Kings            48
#  Rajasthan Royals               46
#  Delhi Daredevils               42
#  Kings XI Punjab                42
#  Sunrisers Hyderabad            27
#  Gujarat Lions                  12
#  Deccan Chargers                11
#  Delhi Capitals                  6
#  Pune Warriors                   6
#  Rising Pune Supergiant          5
#  Kochi Tuskers Kerala            4
#  Rising Pune Supergiants         3
#  Name: winner, dtype: int64]

# %%
bol_win['winner'].value_counts().mean()
# Out:
# 27.066666666666666

# %%
bol_win['winner'].value_counts().median()
# Out:
# 27.0

# %%
sns.distplot(bol_win['winner'].value_counts(),bins=3)

# %%
sns.distplot(bol_win['winner'].value_counts(),bins=3,kde=False)

# %%
sns.distplot(bol_win['winner'].value_counts(),hist=False)

# %%
sns.barplot(bol_win['winner'].value_counts()[:5].keys(),bol_win['winner'].value_counts()[:5])

# %%
sns.barplot(bol_win['winner'].value_counts()[5:10].keys(),bol_win['winner'].value_counts()[5:10])
plt.title("top 5 to 10 eam bar chart")
plt.show()

# %%
plt.pie(bol_win['winner'].value_counts()[5:10],labels=bol_win['winner'].value_counts()[5:10].keys(),autopct='%1.1f%%')


plt.title("Top 5 to 10 team win bolwing 1")
plt.show()

# %%
plt.pie(bol_win['winner'].value_counts()[:5],labels=bol_win['winner'].value_counts()[:5].keys(),autopct='%1.1f%%')
plt.show()

# %%
plt.pie(bol_win['winner'].value_counts(),labels=bol_win['winner'].value_counts().keys(),autopct='%1.1f%%')
plt.title("All Team Comparision bowing 2")
plt.show()

# %%
plt.pie(bol_win['winner'].value_counts()[:10],labels=bol_win['winner'].value_counts()[:10].keys(),autopct='%1.1f%%')
plt.title("Top 10 team bolwing 2")
plt.show()

# %%
# comparing batting first and batting secnd

# %%
sns.lineplot(bat_first_win['winner'].value_counts()[:5].keys(),bat_first_win['winner'].value_counts()[:5],color='red',marker="o",markers=True)
sns.lineplot(bol_win['winner'].value_counts()[:5].keys(),bol_win['winner'].value_counts()[:5],color="aqua")

# %%
plt.pie(bol_win['winner'].value_counts()[:5],labels=bol_win['winner'].value_counts()[:5].keys(),autopct='%1.1f%%',radius=3)
plt.pie(bat_first_win['winner'].value_counts()[:5],labels=bat_first_win['winner'].value_counts()[:5].keys(),autopct='%1.1f%%',colors=["r","orange","g","pink","b"],radius=2)
plt.pie([10],colors=["white"],radius=1)
plt.legend(bat_first_win['winner'].value_counts()[:5].keys())
plt.show()

# %%
#pitch

# %%
df['venue']
# Out:
# 0      Rajiv Gandhi International Stadium, Uppal
# 1        Maharashtra Cricket Association Stadium
# 2         Saurashtra Cricket Association Stadium
# 3                         Holkar Cricket Stadium
# 4                          M Chinnaswamy Stadium
#                          ...
# 751                             Wankhede Stadium
# 752                    M. A. Chidambaram Stadium
# 753                             ACA-VDCA Stadium
# 754                             ACA-VDCA Stadium
# 755           Rajiv Gandhi Intl. Cricket Stadium
# Name: venue, Length: 756, dtype: object

# %%
df['venue'].value_counts()
# Out:
# Eden Gardens                                            77
# M Chinnaswamy Stadium                                   73
# Wankhede Stadium                                        73
# Feroz Shah Kotla                                        67
# Rajiv Gandhi International Stadium, Uppal               56
# MA Chidambaram Stadium, Chepauk                         49
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Maharashtra Cricket Association Stadium                 21
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              17
# Kingsmead                                               15
# Punjab Cricket Association IS Bindra Stadium, Mohali    14
# SuperSport Park                                         12
# Sardar Patel Stadium, Motera                            12
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11
# ...

# %%
df['venue'].head()
# Out:
# 0    Rajiv Gandhi International Stadium, Uppal
# 1      Maharashtra Cricket Association Stadium
# 2       Saurashtra Cricket Association Stadium
# 3                       Holkar Cricket Stadium
# 4                        M Chinnaswamy Stadium
# Name: venue, dtype: object

# %%
df['venue'].value_counts().mean()
# Out:
# 18.4390243902439

# %%
df['venue'].value_counts().median()
# Out:
# 8.0

# %%
df['venue'].value_counts().mode()
# Out:
# 0    7
# dtype: int64

# %%
sns.distplot(df['venue'].value_counts())

# %%
sns.distplot(df['venue'].value_counts(),hist=False)

# %%
sns.distplot(df['venue'].value_counts(),kde=False)

# %%
sns.barplot(df['venue'].value_counts()[:5].keys(),df['venue'].value_counts()[:5])
plt.legend(df['venue'].value_counts().keys())
plt.show()

# %%
plt.pie(df['venue'].value_counts()[:10],labels=df['venue'].value_counts()[:10].keys(),autopct='%1.1f%%')
plt.show()

# %%
d=df[df['win_by_wickets']!=0]['venue']

# %%
d
# Out:
# 1        Maharashtra Cricket Association Stadium
# 2         Saurashtra Cricket Association Stadium
# 3                         Holkar Cricket Stadium
# 5      Rajiv Gandhi International Stadium, Uppal
# 6                               Wankhede Stadium
#                          ...
# 750                            IS Bindra Stadium
# 751                             Wankhede Stadium
# 752                    M. A. Chidambaram Stadium
# 753                             ACA-VDCA Stadium
# 754                             ACA-VDCA Stadium
# Name: venue, Length: 406, dtype: object

# %%
d.value_counts()
# Out:
# Eden Gardens                                            45
# M Chinnaswamy Stadium                                   40
# Wankhede Stadium                                        37
# Feroz Shah Kotla                                        33
# Rajiv Gandhi International Stadium, Uppal               32
# Sawai Mansingh Stadium                                  32
# Punjab Cricket Association Stadium, Mohali              20
# MA Chidambaram Stadium, Chepauk                         18
# Maharashtra Cricket Association Stadium                 14
# Dr DY Patil Sports Academy                              10
# Holkar Cricket Stadium                                   8
# SuperSport Park                                          8
# Punjab Cricket Association IS Bindra Stadium, Mohali     7
# Kingsmead                                                6
# Subrata Roy Sahara Stadium                               6
# Saurashtra Cricket Association Stadium                   6
# ...

# %%
d.value_counts().head()
# Out:
# Eden Gardens                                 45
# M Chinnaswamy Stadium                        40
# Wankhede Stadium                             37
# Feroz Shah Kotla                             33
# Rajiv Gandhi International Stadium, Uppal    32
# Name: venue, dtype: int64

# %%
sns.barplot(d.value_counts()[:5].keys(),d.value_counts()[:5])
plt.legend(d.value_counts().keys())

# %%
plt.pie(d.value_counts()[:10],labels=d.value_counts()[:10].keys(),autopct="%1.1f%%")
plt.show()
